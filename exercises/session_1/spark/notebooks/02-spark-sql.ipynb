# %% [markdown]
# # Spark SQL
#
# This notebook demonstrates how to use Spark SQL to perform data analysis using SQL queries on DataFrames.

# %%
import os
import sys

os.environ['JAVA_HOME'] = '/usr/lib/jvm/java-11-openjdk-amd64'

import pyspark
os.environ['SPARK_HOME'] = pyspark.__path__[0]

os.environ['PATH'] = f"{os.environ['JAVA_HOME']}/bin:{os.environ['SPARK_HOME']}/bin:{os.environ.get('PATH', '')}"

os.environ['PYSPARK_PYTHON'] = sys.executable
os.environ['PYSPARK_DRIVER_PYTHON'] = sys.executable

print(f"JAVA_HOME: {os.environ['JAVA_HOME']}")
print(f"SPARK_HOME: {os.environ['SPARK_HOME']}")
print("Environment configured.")

# %%
# Import necessary libraries
from pyspark.sql import SparkSession
from pyspark.sql.functions import udf, col
from pyspark.sql.types import BooleanType
from pyspark.sql.functions import array
from pyspark.sql.functions import explode

# %%
# Initialize Spark Session
spark = SparkSession.builder \
    .appName("Spark SQL Exercises") \
    .master("local[*]") \
    .getOrCreate()

print("Spark Session Created Successfully!")
print(f"Spark Version: {spark.version}")

# %% [markdown]
# ## Load and familiarize yourself with the dataset

# %%
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, DoubleType

# Re-create the students DataFrame from the previous session for SQL examples
data = [
    ("Alice", 20, 85.5, "Math"),
    ("Bob", 21, 78.0, "Math"),
    ("Charlie", 19, 92.0, "Science"),
    ("David", 22, 88.5, "Science"),
    ("Eve", 20, 95.0, "Math")
]

schema = StructType([
    StructField("name", StringType(), True),
    StructField("age", IntegerType(), True),
    StructField("grade", DoubleType(), True),
    StructField("subject", StringType(), True)
])

df_students = spark.createDataFrame(data, schema=schema)
df_students.createOrReplaceTempView("students")

# %%
# Count students by age and display the results
query = """
SELECT age, count(*) as count
FROM students
GROUP BY age
ORDER BY age
"""
spark.sql(query).show()

# %%
# Create datasets directory to store our csv file
# !mkdir -p ../datasets

# %% [markdown]
# Let's prepare the dataset.
#
# To load the dataset in our "datasets" directory, you have two options:
# 1. **Mount the local data/tickets.csv file** from the repository into your notebook environment in the docker-compose setup.
# 2. **Upload the csv file manually** in this Jupyter environment.
#
# You can find the csv file in the repositoy or download it directly from [this link](https://www.kaggle.com/datasets/tobiasbueck/multilingual-customer-support-tickets?select=dataset-tickets-multi-lang3-4k.csv).

# %%
# Check if you have uploaded the csv file sucessfully.
# !ls -lh ../datasets
# Out:
# total 4,0K
# drwxr-xr-x 2 dalpenyes dalpenyes 4,0K ene 24 11:48 data

# %%
# Read first 5 rows of the csv file
# !head -n 5 ../datasets/data/tickets.csv
# Out:
# subject,body,answer,type,queue,priority,language,business_type,tag_1,tag_2,tag_3,tag_4,tag_5,tag_6,tag_7,tag_8,tag_9
# Problema crítico del servidor requiere atención inmediata,Es necesaria una investigación inmediata sobre la interrupción en el servicio de gestión de AWS que está impactando funciones comerciales esenciales.,Estamos investigando urgentemente el problema con el servicio de gestión de AWS. Proporcionaremos actualizaciones sobre nuestro progreso.,Incident,Technical Support,high,es,IT Services,Urgent Issue,Service Disruption,Incident Report,Service Recovery,System Maintenance,,,,
# Anfrage zur Verfügbarkeit des Dell XPS 13 9310,"Sehr geehrter Kundenservice,
#
# ich hoffe, diese E-Mail erreicht Sie wohl. Ich schreibe, um mich nach der Verfügbarkeit und den Lieferoptionen für das Dell XPS 13 9310 Ultrabook zu erkundigen. Könnten Sie mir bitte mitteilen, ob dieses Modell derzeit auf Lager ist und die geschätzte Lieferzeit zu meinem Standort? Ich bin sehr daran interessiert, es so schnell wie möglich zu kaufen.

# %% [markdown]
# ## Read CSV with Spark

# %%
# Create Dataframe from csv file
ticketsDF = (
    spark.read
        .option("header", True)
        .option("inferSchema", True)
        .option("multiLine", True)
        .option("escape", "\"")                # handle inner quotes
        .csv("../datasets/data/tickets.csv")
)


# Print schema and first 5 rows
ticketsDF.printSchema()
ticketsDF.show(5)
# Out:
# root
#  |-- subject: string (nullable = true)
#  |-- body: string (nullable = true)
#  |-- answer: string (nullable = true)
#  |-- type: string (nullable = true)
#  |-- queue: string (nullable = true)
#  |-- priority: string (nullable = true)
#  |-- language: string (nullable = true)
#  |-- business_type: string (nullable = true)
#  |-- tag_1: string (nullable = true)
#  |-- tag_2: string (nullable = true)
#  |-- tag_3: string (nullable = true)
#  |-- tag_4: string (nullable = true)
#  |-- tag_5: string (nullable = true)
#  |-- tag_6: string (nullable = true)
#  |-- tag_7: string (nullable = true)
#  |-- tag_8: string (nullable = true)
#  |-- tag_9: string (nullable = true)
#
# +--------------------+--------------------+--------------------+--------+-----------------+--------+--------+-----------------+-----------------+------------------+--------------------+----------------+--------------------+------------------+------------------+-----+-----+
# |             subject|                body|              answer|    type|            queue|priority|language|    business_type|            tag_1|             tag_2|               tag_3|           tag_4|               tag_5|             tag_6|             tag_7|tag_8|tag_9|
# +--------------------+--------------------+--------------------+--------+-----------------+--------+--------+-----------------+-----------------+------------------+--------------------+----------------+--------------------+------------------+------------------+-----+-----+
# |Problema crítico ...|Es necesaria una ...|Estamos investiga...|Incident|Technical Support|    high|      es|      IT Services|     Urgent Issue|Service Disruption|     Incident Report|Service Recovery|  System Maintenance|              NULL|              NULL| NULL| NULL|
# |Anfrage zur Verfü...|Sehr geehrter Kun...|Sehr geehrter <na...| Request| Customer Service|     low|      de|Tech Online Store|    Sales Inquiry|   Product Support|    Customer Service|     Order Issue|Returns and Excha...|              NULL|              NULL| NULL| NULL|
# |Erro na Autocompl...|Prezado Suporte a...|Prezado <name>,\n...|Incident|Technical Support|    high|      pt|      IT Services|Technical Support|      Software Bug|  Problem Resolution|    Urgent Issue|          IT Support|              NULL|              NULL| NULL| NULL|
# |Urgent Assistance...|Dear IT Services ...|Dear <name>,\n\nT...| Request|       IT Support|    high|      en|      IT Services|       IT Support|      Urgent Issue|Service Notification|  Cloud Services|  Problem Resolution|Technical Guidance|Performance Tuning| NULL| NULL|
# |Problème d'affich...|Cher équipe de su...|Cher <name>,\n\nM...|Incident|  Product Support|     low|      fr|Tech Online Store|Technical Support|   Product Support|    Hardware Failure|Service Recovery|     Routine Request|              NULL|              NULL| NULL| NULL|
# +--------------------+--------------------+--------------------+--------+-----------------+--------+--------+-----------------+-----------------+------------------+--------------------+----------------+--------------------+------------------+------------------+-----+-----+
# only showing top 5 rows

# %% [markdown]
# ## Recap - Basic Filtering, Grouping & Aggregation

# %%
# Task 1: Show only high-priority tickets
highPriorityDF = ticketsDF.filter(col("priority") == "high")

highPriorityDF.show(truncate=False)
# Out:
# +------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------+-------------------------------+--------+--------+----------------------------+-----------------+------------------+--------------------+------------------+------------------+------------------+--------------------+------------------+-----+
# |subject                                                                             |body                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |answer                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |type    |queue                          |priority|language|business_type               |tag_1            |tag_2             |tag_3               |tag_4             |tag_5             |tag_6             |tag_7               |tag_8             |tag_9|
# +------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------+-------------------------------+--------+--------+----------------------------+-----------------+------------------+--------------------+------------------+------------------+------------------+--------------------+------------------+-----+
# |Problema crítico del servidor requiere atención inmediata                           |Es necesaria una investigación inmediata sobre la interrupción en el servicio de gestión de AWS que está impactando funciones comerciales esenciales.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |Estamos investigando urgentemente el problema con el servicio de gestión de AWS. Proporcionaremos actualizaciones sobre nuestro progreso.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |Incident|Technical Support              |high    |es      |IT Services                 |Urgent Issue     |Service Disruption|Incident Report     |Service Recovery  |System Maintenance|NULL              |NULL                |NULL              |NULL |
# |Erro na Autocompletação de Código do IntelliJ IDEA                                  |Prezado Suporte ao Cliente <name>,\n\nEstou escrevendo para trazer à sua atenção um problema recorrente com o recurso de autocompletação de código no IntelliJ IDEA 2024.1. Este problema específico faz com que o aplicativo travar frequentemente durante o desenvolvimento, o que está prejudicando significativamente minha produtividade. Cada vez que tento usar o recurso de autocompletação de código, o software fica sem resposta, levando eventualmente a um travamento. Já tentei os passos comuns de solução de problemas, como reinstalação e aplicação das atualizações mais recentes, mas o problema persiste. Agradeceria sua orientação sobre como resolver esse problema o mais rápido possível. Obrigado pela sua atenção.\n\nAtenciosamente,\n<name>                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |Prezado <name>,\n\nObrigado por entrar em contato e nos informar sobre o problema com o recurso de autocompletação de código no IntelliJ IDEA 2024.1. Entendemos o quão crucial essa ferramenta é para o seu trabalho de desenvolvimento.\n\nPara ajudá-lo melhor, por favor, tente os seguintes passos:\n1. Verifique a compatibilidade do seu sistema com o IntelliJ IDEA 2024.1.\n2. Limpe o cache da IDE acessando Arquivo > Invalidar Caches / Reiniciar.\n3. Desative quaisquer plugins desnecessários para ver se estão causando conflitos.\n4. Aumente a alocação de memória para o aplicativo por meio das opções de VM.\n\nSe o problema persistir, por favor, nos envie os logs (localizados em Ajuda > Coletar Logs) para uma análise mais profunda. Estamos comprometidos em resolver esse problema o mais rápido possível.\n\nAtenciosamente,\nEquipe de Suporte ao Cliente                                                                                                                                                                                                                           |Incident|Technical Support              |high    |pt      |IT Services                 |Technical Support|Software Bug      |Problem Resolution  |Urgent Issue      |IT Support        |NULL              |NULL                |NULL              |NULL |
# |Urgent Assistance Required: AWS Service                                             |Dear IT Services Support Team, \n\nI am reaching out regarding a high-priority ticket related to our AWS Management Service. We are experiencing significant challenges in deploying services and optimizing our cloud infrastructure costs. It is crucial for us to gain clarity and efficient solutions on this matter. \n\nWe have been noticing higher-than-expected expenditure, and the deployment process appears to have several hurdles that prevent smooth operation. As this is affecting our operational efficiency and financial planning, your expert assistance is urgently requested. \n\nCould you please prioritize this ticket and guide us on the best practices to streamline deployment and manage costs effectively on AWS? Your prompt response will greatly aid in mitigating potential losses and optimizing current systems. \n\nThank you for your immediate attention and expertise.\n\nBest regards, \n\n<name>\n<acc_num>\n<name@example.com>\n<tel_num>                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |Dear <name>,\n\nThank you for reaching out regarding your AWS Management Service issues. I understand the urgency and the impact on your operational efficiency and financial planning. We will prioritize your ticket and escalate it to our AWS specialists who will contact you shortly. \n\nIn the meantime, please ensure your AWS account details are handy, as it will facilitate a more efficient troubleshooting process. They will assist you in optimizing your cloud infrastructure costs and streamlining your deployment process. \n\nWe are committed to providing a solution quickly to minimize any potential losses. Thank you for your patience and cooperation.\n\nBest regards,\nIT Services Support Team                                                                                                                                                                                                                                                                                                                                                                                      |Request |IT Support                     |high    |en      |IT Services                 |IT Support       |Urgent Issue      |Service Notification|Cloud Services    |Problem Resolution|Technical Guidance|Performance Tuning  |NULL              |NULL |
# |Urgent: Issue with Zoom Screen Sharing Feature                                      |Dear Customer Support,\n\nI am experiencing a high-priority incident wherein screen sharing fails during critical business webinar sessions using Zoom version 5.11.0. This issue is disrupting our operations and needs immediate attention.\n\nCould you please address this matter as soon as possible or direct me to someone who can assist?\n\nThank you for your urgent support.\n\nBest regards,\n\n<name>\n<acc_num>                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |Dear <name>,\n\nThank you for reaching out. We understand the urgency of the screen sharing issue with Zoom version 5.11.0 during your webinars. We recommend updating to the latest Zoom version, as many issues can be resolved with updates. If the problem persists after updating, please contact our technical team directly at <tel_num> for immediate assistance.\n\nBest regards,\nCustomer Support Team                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |Incident|Technical Support              |high    |en      |IT Services                 |Technical Support|Urgent Issue      |Service Disruption  |Problem Resolution|Software Bug      |NULL              |NULL                |NULL              |NULL |
# |Service outage resolution requested for ongoing issues                              |Dear IT Services Customer Support,\n\nI am writing to express our concern regarding a recent service outage that severely disrupted our regular operations. This was specifically related to the IT Consulting Service provided by your team. The interruption significantly impacted our workflow, causing delays and potential revenue loss.\n\nTo prevent similar issues in the future, we are seeking your expertise in developing and implementing comprehensive IT solutions. Considering the critical nature of our operations, it is imperative that we ensure maximum uptime and reliability from all IT-related services.\n\nWe appreciate the prompt support and preventive measures your company can offer. It would be highly beneficial to discuss possible solutions that can enhance our system's resilience and reduce vulnerability to unexpected outages.\n\nMoreover, please let us know if there are maintenance services or upgrades that should be scheduled to optimize performance and reliability in our existing infrastructure. Kindly provide us with a detailed proposal at your earliest convenience.\n\nThank you for your attention to this critical matter. We look forward to your swift action and partnership to effectively resolve these issues.\n\nSincerely,\n\n<name>\n<tel_num>\n<acc_num>                                                                                                                                                                                                                                                                   |Dear <name>,\n\nThank you for reaching out to us regarding the recent service outage affecting your IT Consulting Service. We sincerely apologize for any disruption caused to your operations.\n\nWe understand the importance of ensuring maximum uptime and reliability. Our team is committed to analyzing this issue thoroughly to prevent future occurrences and will set up a plan for comprehensive IT solutions. We will also evaluate your current infrastructure to propose necessary upgrades or maintenance services to optimize performance and reliability.\n\nTo address this promptly, let's schedule a meeting to discuss specific solutions and strategies tailored to your needs. We will prepare a detailed proposal outlining the steps we can take to enhance your system's resilience.\n\nWe appreciate your trust in us and are dedicated to working closely with you to swiftly resolve these issues. Please expect our proposal shortly.\n\nThank you for your patience and understanding.\n\nBest regards,\n\nCustomer Support Team  \nIT Services                                      |Change  |Service Outages and Maintenance|high    |en      |IT Services                 |Service Outage   |IT Support        |Problem Resolution  |Technical Support |Service Recovery  |System Maintenance|Performance Tuning  |Urgent Issue      |NULL |
# |Unterstützung beim Einrichten des drahtlosen Druckens                               |Sehr geehrter Support des Tech Online Stores,\n\nich benötige Hilfe beim Einrichten meines Epson EcoTank ET-4760 für drahtloses Drucken mit mehreren Geräten zu Hause. Ich freue mich auf Ihre Unterstützung.\n\nVielen Dank,\n\n<name>                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |Sehr geehrter <name>, um Ihren Epson EcoTank ET-4760 für drahtloses Drucken einzurichten, stellen Sie bitte sicher, dass er mit Ihrem Wi-Fi verbunden ist. Laden Sie die Epson Connect-App auf jedem Gerät für die Einrichtung herunter.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            |Request |Product Support                |high    |de      |Tech Online Store           |Technical Support|Product Support   |IT Support          |Problem Resolution|NULL              |NULL              |NULL                |NULL              |NULL |
# |Solicitud urgente de orientación y solución de problemas                            |Estimado soporte al cliente, espero que este mensaje le encuentre bien. Me pongo en contacto para solicitar urgentemente su experiencia en orientación sobre desarrollo de software y solución de problemas del servidor como parte de nuestro actual proyecto de consultoría de TI. Hemos encontrado algunos problemas críticos que están afectando negativamente nuestros plazos del proyecto. Específicamente, nuestro equipo está enfrentando desafíos con la integración del nuevo software con nuestros sistemas existentes, lo que ha llevado a tiempos de inactividad inesperados y retrasos en el rendimiento. Además, ha habido problemas persistentes de conectividad del servidor que no podemos resolver por nuestra cuenta, obstaculizando la entrega fluida de nuestros servicios. Su pronta asistencia en el diagnóstico y rectificación de estos problemas sería inmensamente beneficiosa. Confiamos en su amplia experiencia y destreza técnica para ayudarnos a superar estos obstáculos rápidamente. ¿Podría también organizar una consulta con su desarrollador líder a la mayor brevedad posible? Nuestro objetivo es resolver estos problemas lo más rápido posible para minimizar cualquier retraso adicional en el proyecto y garantizar una experiencia fluida para el cliente. Gracias por su atención inmediata a este asunto. Espero su respuesta rápida. Saludos cordiales, <name>                                                                                                                                                                                        |Estimado <name>,\n\nGracias por ponerte en contacto con nosotros. Entendemos la urgencia de tu situación y estamos comprometidos a proporcionarte el apoyo necesario. Para abordar los problemas de integración de software y conectividad del servidor que estás experimentando, organizaremos una consulta con nuestro desarrollador líder en el momento más pronto posible. Nuestro equipo trabajará estrechamente contigo para diagnosticar y resolver estos desafíos de manera eficiente.\n\nPor favor, confirma tus horarios disponibles para esta consulta y cualquier detalle específico relacionado con la integración del sistema y los problemas del servidor que has encontrado. Esta información nos ayudará a preparar soluciones personalizadas para minimizar el tiempo de inactividad y los retrasos en el rendimiento.\n\nAgradecemos tu paciencia y confianza en nuestra experiencia.\n\nSaludos cordiales,\nEquipo de soporte al cliente                                                                                                                                                        |Request |Technical Support              |high    |es      |IT Consulting Firm          |Technical Support|IT Support        |Problem Resolution  |System Crash      |Service Disruption|Urgent Issue      |Software Bug        |Network Issue     |NULL |
# |Urgente: Interrupción de red por el router ISR4331                                  |Estimado equipo de soporte, Estamos experimentando una interrupción de red causada por un router Cisco ISR4331 que no funciona correctamente. Esto requiere una intervención técnica de alta prioridad. Por favor, aborden este problema lo antes posible. Gracias por su asistencia. Saludos, <name>                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |Estimado <name>,\n\nGracias por ponerse en contacto. Entendemos la urgencia de la interrupción de la red causada por el router Cisco ISR4331. Nuestro equipo técnico ha sido notificado de inmediato y abordará este problema como prioridad. Nuestro objetivo es resolverlo lo más rápido posible y lo mantendremos informado sobre el progreso.\n\nAtentamente,\nEquipo de soporte                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |Incident|IT Support                     |high    |es      |IT Services                 |Network Issue    |Service Disruption|Urgent Issue        |Technical Support |NULL              |NULL              |NULL                |NULL              |NULL |
# |Immediate Assistance Required for Network Disruption                                |Dear Customer Support,\n\nWe are currently experiencing a high-priority incident involving our Cisco Router ISR4331, which is causing significant disruptions to our enterprise network performance. This issue has led to a partial outage affecting several critical operations. We kindly request your immediate attention and expertise to resolve this issue as quickly as possible.\n\nPlease provide guidance on the next steps for troubleshooting or confirm the dispatch of a technical team. You may reach me at our direct line: <tel_num> or email at <email_address>.\n\nThank you for your prompt response.\n\nBest regards,\n\n<name>\n<company_name>                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |Dear <name>,\n\nThank you for reaching out to us regarding the network disruption involving your Cisco Router ISR4331. We understand the urgency and impact of this issue.\n\nTo begin troubleshooting, please ensure that all physical connections are secure and restart the router if possible. Additionally, verify that the firmware is up to date. If the problem persists, we will escalate the issue and arrange for a technical team to assist you.\n\nPlease keep us updated via email or the direct telephone number provided. Our team is on standby to provide further support and coordinate the necessary steps for resolution. \n\nThank you for your patience and cooperation.\n\nBest regards,\n\nCustomer Support Team                                                                                                                                                                                                                                                                                                                                                                           |Incident|Service Outages and Maintenance|high    |en      |IT Services                 |Network Issue    |Service Disruption|Urgent Issue        |Technical Support |Incident Report   |Problem Resolution|Service Recovery    |NULL              |NULL |
# |NULL                                                                                |Dear Customer Support, \n\nI hope this message finds you well. I am writing to request a detailed explanation of some unexpected monthly charges for AWS cloud resources as seen on my last bill. The charges seem unaccounted for, and since I utilize the AWS Management Service, it would be helpful for me to understand the breakdown. Would you please help clarify these charges? My account number is <acc_num>. For further correspondence, you can reach me at <nameemail>@domain.com or call me at <tel_num>. Your prompt assistance with this matter is appreciated. \n\nThank you. \n\nBest regards, \n<name>                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |Dear <name>,\n\nThank you for reaching out to us. We understand your concern about the unexpected AWS charges. We will review your account details to provide a detailed explanation and breakdown of the charges on your latest bill. Our team is committed to resolving this matter promptly.\n\nFor privacy and security, we recommend discussing further details through the email or phone number you have provided. Please expect a follow-up from our side shortly.\n\nThank you for your patience and understanding.\n\nBest regards, \nCustomer Support Team                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |Request |Billing and Payments           |high    |en      |IT Services                 |Billing Issue    |Account Assistance|Payment Processing  |Customer Service  |General Inquiry   |NULL              |NULL                |NULL              |NULL |
# |Problema recurrente de desconexión de red                                           |Estimado soporte al cliente,\n\nEspero que este mensaje le llegue en buen estado. Me pongo en contacto con usted para informarle sobre un problema recurrente que estamos enfrentando con desconexiones frecuentes de la red. Después de realizar una investigación exhaustiva, hemos concluido que estas interrupciones se deben a un problema de configuración en nuestro Cisco Router ISR4331, que es esencial para nuestras operaciones de red.\n\nEste problema se manifiesta como una pérdida esporádica de conectividad de red, afectando gravemente tanto nuestras comunicaciones internas como externas. La creciente frecuencia de estas desconexiones se está volviendo cada vez más perjudicial para nuestras operaciones, resultando en una reducción de la productividad y potencialmente obstaculizando nuestra entrega de servicios.\n\nCreemos que la configuración actual del Cisco Router ISR4331 puede no estar adaptada a nuestros requisitos específicos de red, o podría haber un problema subyacente de firmware o compatibilidad. Dado que esta situación está más allá de nuestra área de experiencia, solicitamos respetuosamente su pronta asistencia para diagnosticar y proponer una solución a este problema.\n\nPor favor, háganos saber tan pronto como sea posible cómo podemos abordar este asunto de manera eficiente. Si necesita contactarme para obtener más información o diagnósticos remotos, no dude en comunicarse directamente conmigo.\n\nGracias por su rápida atención a este importante problema.\n\nAtentamente,\n\n<name>\n<email_address>\n<tel_num>|Estimado <name>,\n\nGracias por contactarnos sobre los desafíos de desconexión de red con su Cisco Router ISR4331. Reconocemos la dificultad que esta situación ha presentado y estamos aquí para ayudarle.\n\nPara abordar este problema de manera efectiva, le recomendamos establecer una sesión de diagnóstico remoto con nuestro equipo de soporte técnico. Por favor, comparta un momento conveniente para esta sesión y asegúrese de que el acceso remoto al router afectado sea factible. Si tiene algún registro de error o actualizaciones recientes de firmware, le agradeceríamos que nos los enviara.\n\nAdemás, una rápida evaluación inicial del firmware y la configuración actual del router puede resaltar problemas conocidos que podemos resolver rápidamente.\n\nNuestro objetivo es reducir cualquier interrupción adicional y restaurar la funcionalidad completa de la red lo más rápido posible. No dude en contactarnos para obtener información adicional en cualquier momento.\n\nGracias por su comprensión y paciencia en este asunto.\n\nAtentamente,\n\nEquipo de soporte al cliente|Incident|Technical Support              |high    |es      |IT Services                 |Network Issue    |Technical Support |Problem Resolution  |Service Disruption|Urgent Issue      |Technical Guidance|NULL                |NULL              |NULL |
# |Problemas intermitentes de exibição após atualização de firmware                    |Caro Suporte ao Cliente,\n\n Estou entrando em contato para relatar um problema com meu Samsung QLED QN90A que comprei em sua loja. Após a recente atualização de firmware, estou enfrentando problemas intermitentes de exibição. A tela às vezes pisca e às vezes perde o sinal completamente, o que prejudica significativamente minha experiência de visualização.\n\n Esses problemas começaram a ocorrer imediatamente após a atualização de firmware, sugerindo uma possível causa. Tentei solucionar o problema verificando todas as conexões e reiniciando a TV para as configurações de fábrica, mas o problema persiste.\n\n Você poderia me fornecer orientações sobre como resolver isso ou me informar os próximos passos? Se um retrocesso de firmware ou uma correção estiver disponível, isso seria extremamente útil para recuperar a funcionalidade total da minha TV.\n\n Obrigado antecipadamente pela sua assistência. Aguardo uma solução rápida.\n\n Atenciosamente,\n\n <name>\n <email>\n <tel_num>                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |Caro <name>,\n\n Obrigado por entrar em contato e pela sua paciência. Lamentamos saber sobre os problemas de exibição após a atualização de firmware em sua Samsung QLED QN90A.\n\n Para resolver isso, por favor, assegure-se de que o software da sua TV esteja atualizado com os últimos patches do site de suporte da Samsung. Se o problema persistir, recomendamos um retrocesso de firmware, se disponível, com o qual podemos ajudá-lo. Além disso, nosso centro de serviços pode diagnosticar e resolver o problema, se necessário.\n\n Entre em contato conosco pelo <tel_num> ou visite o centro de serviços mais próximo com o comprovante de compra. Pedimos desculpas pelo inconveniente e estamos comprometidos em resolver isso rapidamente.\n\n Atenciosamente,\n\n Equipe de Suporte ao Cliente                                                                                                                                                                                                                                                                                                   |Problem |Product Support                |high    |pt      |Tech Online Store           |Technical Support|Product Support   |Software Bug        |Technical Guidance|Problem Resolution|NULL              |NULL                |NULL              |NULL |
# |Fehler bei der Code-Vervollständigung in IntelliJ IDEA                              |Sehr geehrter <name> Kundenservice,\n\nich schreibe, um Ihre Aufmerksamkeit auf ein wiederkehrendes Problem mit der Code-Vervollständigung in IntelliJ IDEA 2024.1 zu lenken. Dieses bestimmte Problem führt häufig dazu, dass die Anwendung während der Entwicklung abstürzt, was meine Produktivität erheblich beeinträchtigt. Jedes Mal, wenn ich versuche, die Code-Vervollständigungsfunktion zu verwenden, wird die Software unresponsiv und führt schließlich zu einem Absturz. Ich habe die üblichen Fehlerbehebungsmaßnahmen wie die Neuinstallation und das Anwenden der neuesten Updates ausprobiert, aber das Problem besteht weiterhin. Ich würde Ihre Anleitung zur Lösung dieses Problems so schnell wie möglich schätzen. Vielen Dank für Ihre Aufmerksamkeit.\n\nMit freundlichen Grüßen,\n<name>                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |Sehr geehrter <name>,\n\nvielen Dank, dass Sie sich an uns gewandt haben und uns über das Problem mit der Code-Vervollständigung in IntelliJ IDEA 2024.1 informiert haben. Wir verstehen, wie wichtig dieses Werkzeug für Ihre Entwicklungsarbeit ist.\n\nUm Ihnen besser helfen zu können, versuchen Sie bitte die folgenden Schritte:\n1. Überprüfen Sie die Kompatibilität Ihres Systems mit IntelliJ IDEA 2024.1.\n2. Leeren Sie den Cache der IDE, indem Sie zu Datei > Caches ungültig machen / neu starten gehen.\n3. Deaktivieren Sie alle unnötigen Plugins, um herauszufinden, ob sie Konflikte verursachen.\n4. Erhöhen Sie die Speicherzuweisung für die Anwendung über die VM-Optionen.\n\nWenn das Problem weiterhin besteht, senden Sie uns bitte die Protokolle (zu finden unter Hilfe > Protokolle sammeln) zur weiteren Analyse. Wir sind bestrebt, dieses Problem so schnell wie möglich zu lösen.\n\nMit freundlichen Grüßen,\nDas Kundenserviceteam                                                                                                                                            |Incident|Technical Support              |high    |de      |IT Services                 |Technical Support|Software Bug      |System Crash        |Problem Resolution|Technical Guidance|NULL              |NULL                |NULL              |NULL |
# ...
# |Asistencia Urgente Requerida para Problemas de Conectividad del Router Cisco ISR4331|Estimado Soporte al Cliente,\n\nEstoy experimentando problemas de conectividad con nuestro router Cisco ISR4331, lo que está afectando el rendimiento de nuestra red empresarial y las comunicaciones seguras. Este ha sido un problema urgente, que afecta las operaciones diarias. ¿Podrían por favor brindar asistencia urgente para resolver este asunto lo antes posible? Su experiencia y acción rápida en esta situación serían muy apreciadas.\n\nGracias de antemano por su cooperación.\n\nSaludos cordiales,\n\n<name>                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |Estimado <name>,\n\nGracias por contactarnos acerca de los problemas de conectividad con su router Cisco ISR4331. Entendemos la urgencia de esta situación y su impacto en sus operaciones. Por favor, asegúrese primero de que todas las conexiones y configuraciones estén correctamente establecidas de acuerdo con el manual del router. Si el problema persiste, sugerimos reiniciar el dispositivo y verificar cualquier cambio reciente en la red o configuraciones del firewall que puedan afectar la conectividad.\n\nSi el problema continúa, le solicitamos que reúna detalles como mensajes de error, el entorno de la red y cualquier modificación reciente. Esto ayudará a nuestro equipo técnico a proporcionar una solución más eficiente.\n\nPor favor, háganos saber su disponibilidad para más asistencia en la solución de problemas.\n\nSaludos cordiales,\nSoporte al Cliente                                                                                                                                                                                                                 |Incident|Technical Support              |high    |es      |IT Services                 |Technical Support|Urgent Issue      |Network Issue       |Problem Resolution|Service Disruption|NULL              |NULL                |NULL              |NULL |
# |Urgent: Jira Software 8.20 Outage                                                   |Dear Customer Support Team, \n\nI am writing to report a critical issue we are experiencing with the Jira Software, version 8.20, used for managing our project tasks and tracking. The system is down, impacting our team's ability to view and update project statuses across multiple departments. This outage is causing significant disruptions in our workflow, hindering communication and collaboration among team members.\n\nWe urge you to look into this issue immediately and provide a timeline for when the system will be operational again. Our projects heavily depend on Jira for task assignment and progress tracking, making this an urgent matter.\n\nThank you for your prompt attention to this pressing issue.\n\nBest regards,\n\n<name>\n\n<tel_num> \n\n<acc_num>                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |Dear <name>,\n\nThank you for bringing this urgent issue to our attention. We apologize for the inconvenience caused by the Jira Software 8.20 outage. Our team is currently investigating the problem to restore full functionality as quickly as possible. We understand the importance of resolving this to prevent further disruptions in your workflow. We will keep you updated with progress and provide a timeline for when the system will be operational as soon as possible. If you have any further questions, please reach out at any time.\n\nBest regards,\n\nCustomer Support Team                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |Problem |Technical Support              |high    |en      |Software Development Company|Service Outage   |Urgent Issue      |Incident Report     |Service Disruption|Technical Support |NULL              |NULL                |NULL              |NULL |
# |NULL                                                                                |Prezado <name>,\n\nSentimos muito ao saber sobre o atraso na entrega do seu Apple Watch Series 7 GPS. Compreendemos sua preocupação e estamos atualmente investigando o problema. Esperamos que seu pacote chegue em breve. Pedimos desculpas por quaisquer transtornos que isso possa ter ocasionado e agradecemos sua compreensão. Se você tiver mais dúvidas, entre em contato conosco pelo <tel_num> ou responda este e-mail.\n\nAgradecemos por escolher nossa loja online!\n\nCordialmente,\nEquipe de Atendimento ao Cliente                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |Prezado Equipe de Atendimento ao Cliente,\n\nAgradeço pela atualização acerca do atraso no envio do meu Apple Watch Series 7 GPS. Valorizo os esforços de vocês para solucionar a situação e estou otimista de que o pacote chegará em breve. Entrarei em contato caso tenha mais dúvidas.\n\nCordialmente,\n[Seu Nome]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |Request |Technical Support              |high    |pt      |Online Store                |Customer Service |Order Issue       |Shipment Delay      |Problem Resolution|General Inquiry   |NULL              |NULL                |NULL              |NULL |
# |Dringend: Verbindungs- und Leistungsproblem                                         |Sehr geehrter Kundendienst, \n\nich schreibe, um ein sofortiges Problem bezüglich der sicheren Verbindung und Leistung zu melden, das unsere Unternehmensabläufe während der Geschäftszeiten kritisch beeinträchtigt. Wir sind auf den Cisco Router ISR4331 als Kernkomponente unserer IT-Infrastruktur angewiesen, und kürzliche Störungen haben unsere Fähigkeit zur Aufrechterhaltung der funktionalen Verbindung und Systemleistung erheblich beeinträchtigt. Die häufigen Ausfälle und Verzögerungen haben nicht nur interne Prozesse, sondern auch unsere Servicebereitstellung an Kunden betroffen. Dieses Problem erfordert schnelle Aufmerksamkeit, um die Fehlersuche und -behebung zu erleichtern. Wir bitten um die sofortige Unterstützung Ihres Teams bei der Diagnose und Behebung des Problems. Vielen Dank für Ihre sofortige Unterstützung. \n\nMit freundlichen Grüßen, \n<name> \n<position> \n<company> \n<tel_num>                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |Sehr geehrter <name>,\n\nvielen Dank, dass Sie sich wegen dieses kritischen Problems an uns gewandt haben. Wir verstehen die Schwere der Unterbrechungen bei der Verbindung und Leistung, die Ihre Betriebsabläufe beeinträchtigen. Unser technisches Team wurde benachrichtigt und arbeitet daran, das Problem mit Ihrem Cisco Router ISR4331 zu priorisieren und zu bewerten. Wir streben an, dieses Anliegen umgehend zu diagnostizieren und zu lösen, um die vollständige Funktionalität Ihres Unternehmens wiederherzustellen. Bitte erwarten Sie in Kürze unser detailliertes Follow-up. Für sofortige Unterstützung können Sie unser Support-Hotline unter <support_tel_num> kontaktieren.\n\nMit freundlichen Grüßen,  \nKundendienst                                                                                                                                                                                                                                                                                                                                                                       |Incident|Technical Support              |high    |de      |IT Services                 |Urgent Issue     |Technical Support |Network Issue       |Service Disruption|Problem Resolution|System Crash      |Performance Tuning  |NULL              |NULL |
# +------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------+-------------------------------+--------+--------+----------------------------+-----------------+------------------+--------------------+------------------+------------------+------------------+--------------------+------------------+-----+
# only showing top 20 rows

# %%
# Task 2: Return the number of tickets by type (Incident, Request…), ordering them from biggest amount to least
ticketsByTypeDF = ticketsDF.groupBy("type").count().orderBy(col("count").desc())

ticketsByTypeDF.show()
# Out:
# +--------+-----+
# |    type|count|
# +--------+-----+
# |Incident| 1608|
# | Request| 1097|
# | Problem|  853|
# |  Change|  442|
# +--------+-----+

# %%
## Task 3: Count tickets by language
ticketsByLangDF = ticketsDF.groupBy("language").count().orderBy(col("count").desc())

ticketsByLangDF.show()
# Out:
# +--------+-----+
# |language|count|
# +--------+-----+
# |      en| 1391|
# |      de|  848|
# |      es|  812|
# |      fr|  476|
# |      pt|  473|
# +--------+-----+

# %% [markdown]
# ## SQL Exercises
#
# In order to use SQL query language, we need to register a table based on our DataFrame.

# %%
ticketsDF.createOrReplaceTempView("tickets")

# %%
# Show first 5 rows
spark.sql("""
SELECT * FROM tickets
LIMIT 5
""").show()
# Out:
# +--------------------+--------------------+--------------------+--------+-----------------+--------+--------+-----------------+-----------------+------------------+--------------------+----------------+--------------------+------------------+------------------+-----+-----+
# |             subject|                body|              answer|    type|            queue|priority|language|    business_type|            tag_1|             tag_2|               tag_3|           tag_4|               tag_5|             tag_6|             tag_7|tag_8|tag_9|
# +--------------------+--------------------+--------------------+--------+-----------------+--------+--------+-----------------+-----------------+------------------+--------------------+----------------+--------------------+------------------+------------------+-----+-----+
# |Problema crítico ...|Es necesaria una ...|Estamos investiga...|Incident|Technical Support|    high|      es|      IT Services|     Urgent Issue|Service Disruption|     Incident Report|Service Recovery|  System Maintenance|              NULL|              NULL| NULL| NULL|
# |Anfrage zur Verfü...|Sehr geehrter Kun...|Sehr geehrter <na...| Request| Customer Service|     low|      de|Tech Online Store|    Sales Inquiry|   Product Support|    Customer Service|     Order Issue|Returns and Excha...|              NULL|              NULL| NULL| NULL|
# |Erro na Autocompl...|Prezado Suporte a...|Prezado <name>,\n...|Incident|Technical Support|    high|      pt|      IT Services|Technical Support|      Software Bug|  Problem Resolution|    Urgent Issue|          IT Support|              NULL|              NULL| NULL| NULL|
# |Urgent Assistance...|Dear IT Services ...|Dear <name>,\n\nT...| Request|       IT Support|    high|      en|      IT Services|       IT Support|      Urgent Issue|Service Notification|  Cloud Services|  Problem Resolution|Technical Guidance|Performance Tuning| NULL| NULL|
# |Problème d'affich...|Cher équipe de su...|Cher <name>,\n\nM...|Incident|  Product Support|     low|      fr|Tech Online Store|Technical Support|   Product Support|    Hardware Failure|Service Recovery|     Routine Request|              NULL|              NULL| NULL| NULL|
# +--------------------+--------------------+--------------------+--------+-----------------+--------+--------+-----------------+-----------------+------------------+--------------------+----------------+--------------------+------------------+------------------+-----+-----+

# %%
# Task 4: Count tickets by priority (SQL version)
spark.sql("""
SELECT priority, COUNT(*) as count
FROM tickets
GROUP BY priority
ORDER BY count DESC
""").show()
# Out:
# +--------+-----+
# |priority|count|
# +--------+-----+
# |    high| 1649|
# |  medium| 1603|
# |     low|  748|
# +--------+-----+

# %%
# Task 5: Which ticket subjects contain the keyword “Account” (SQL version)
spark.sql("""
SELECT * FROM tickets
WHERE subject LIKE '%Account%'
""").show(truncate=False)
# Out:
# +------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+--------------------+--------+--------+------------------+-----------------+----------------+------------------+------------------+--------------------+------------------+---------------+----------+-----+
# |subject                                                                 |body                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |answer                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |type   |queue               |priority|language|business_type     |tag_1            |tag_2           |tag_3             |tag_4             |tag_5               |tag_6             |tag_7          |tag_8     |tag_9|
# +------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+--------------------+--------+--------+------------------+-----------------+----------------+------------------+------------------+--------------------+------------------+---------------+----------+-----+
# |Vorgeschlagene Verbesserungen für das AWS-Multi-Account-Cloud-Management|Sehr geehrte IT-Consulting-Firmenunterstützung,\n\nich schreibe, um Verbesserungen für die Verwaltung der Cloud-Infrastruktur über mehrere AWS-Konten vorzuschlagen, mit dem Fokus auf die Verbesserung der Compliance und des Kostenmanagements. Unser aktuelles AWS-Management-Service fehlt es an einheitlicher Überwachung und proaktiven Compliance-Prüfungen, was betriebliche Risiken darstellt.\n\nUm diese Probleme anzugehen, schlage ich vor, bessere Analysen über Konten hinweg und automatisierte Kostenmanagement-Tools zu implementieren. Diese Verbesserungen könnten die Effizienz erheblich steigern, indem sie die Einhaltung von Richtlinien sicherstellen und die Abrechnung von Ressourcen optimieren.\n\nBitte ziehen Sie diesen Vorschlag in Betracht und informieren Sie uns über weitere erforderliche Gespräche, um mit diesen Verbesserungen zu beginnen.\n\nVielen Dank.\n\nMit freundlichen Grüßen,\n\n<name>\n\n<tel_num>                      |Sehr geehrter <name>,\n\nvielen Dank für Ihren Vorschlag zu Verbesserungen im Management der AWS-Cloud-Infrastruktur. Wir schätzen Ihre Vorschläge zur Verbesserung der Compliance und des Kostenmanagements über mehrere Konten. Die Implementierung von Analysen über Konten hinweg und automatisierten Kostenmanagement-Tools klingt vielversprechend zur Optimierung der Effizienz und Einhaltung von Richtlinien.\n\nWir werden Ihren Vorschlag intern prüfen und uns bei Ihnen melden, falls wir weitere Diskussionen führen müssen, um mit diesen Verbesserungen fortzufahren.\n\nVielen Dank, dass Sie sich an uns gewandt haben.\n\nMit freundlichen Grüßen,\nIT-Consulting-Firmenunterstützung                              |Request|Technical Support   |high    |de      |IT Consulting Firm|Technical Support|Product Support |Feature Request   |System Maintenance|General Inquiry     |Problem Resolution|NULL           |NULL      |NULL |
# |Request to Adjust AWS Billing Accounts                                  |Dear IT Services Support Team,\n\nI would like to request an adjustment to our AWS billing accounts for the cloud infrastructure services managed under the AWS Management Service. It is essential to review and correct any discrepancies. Please prioritize this medium-priority request as soon as possible.\n\nThank you in advance for your assistance.\n\nBest regards,\n<name>\n<acc_num>                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |Dear <name>,\n\nThank you for reaching out. We have received your request to adjust the AWS billing accounts and will begin reviewing the discrepancies promptly. Please allow us some time to investigate and correct any issues.\n\nWe appreciate your patience and understanding.\n\nBest regards,\nIT Services Support Team                                                                                                                                                                                                                                                                                                                                                                                                       |Change |Billing and Payments|medium  |en      |IT Services       |Billing Issue    |Customer Service|Payment Processing|Account Assistance|Problem Resolution  |NULL              |NULL           |NULL      |NULL |
# |Issue with Security Settings Update in AWS Accounts                     |Dear Customer Support,\n\nI am writing to report an issue with the ticket originally marked problematic regarding updating security settings in AWS accounts managed by our AWS Management Service. We are experiencing difficulties and require assistance in resolving this matter promptly. Your immediate attention to this issue would be greatly appreciated.\n\nThank you in advance for your support.\n\nBest regards,\n<name>\n<company_name>                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |Dear <name>,\n\nThank you for reaching out. We understand the urgency of updating the security settings in your AWS accounts. Our team is looking into the issue and will get back to you shortly with a resolution. We appreciate your patience and will update you as soon as possible.\n\nBest regards,\nCustomer Support                                                                                                                                                                                                                                                                                                                                                                                                          |Change |Product Support     |medium  |en      |IT Consulting Firm|Technical Support|Account Security|Urgent Issue      |Problem Resolution|Service Notification|NULL              |NULL           |NULL      |NULL |
# |Vorgeschlagene Verbesserungen für das AWS Multi-Account Cloud Management|Sehr geehrte IT-Beratung Support,\n\nich schreibe, um Verbesserungen für die Verwaltung von Cloud-Infrastrukturen über mehrere AWS-Konten vorzuschlagen, wobei der Schwerpunkt auf der Verbesserung der Compliance und des Kostenmanagements liegt. Unser aktueller AWS Management Service fehlt es an einheitlicher Überwachung und proaktiven Compliance-Prüfungen, was operationale Risiken mit sich bringt.\n\nUm diese Probleme anzugehen, schlage ich vor, bessere Analysen über Konten hinweg und automatisierte Kostenmanagement-Tools implementieren. Diese Verbesserungen könnten die Effizienz erheblich steigern, indem sie die Einhaltung von Richtlinien sicherstellen und die Abrechnung von Ressourcen optimieren.\n\nBitte ziehen Sie diesen Vorschlag in Betracht und informieren Sie uns über etwaige weitere Diskussionen, die erforderlich sind, um diese Verbesserungen zu initiieren.\n\nVielen Dank.\n\nMit freundlichen Grüßen,\n\n<name>\n\n<tel_num>|Sehr geehrter <name>,\n\nvielen Dank für Ihren Vorschlag bezüglich der Verbesserungen in der Verwaltung der AWS-Cloud-Infrastruktur. Wir schätzen Ihre Vorschläge zur Verbesserung der Compliance und des Kostenmanagements über mehrere Konten hinweg. Die Implementierung von Analysen über Konten hinweg und automatisierten Kostenmanagement-Tools scheint vielversprechend zu sein, um die Effizienz und die Einhaltung von Richtlinien zu optimieren.\n\nWir werden Ihren Vorschlag intern prüfen und uns bei Ihnen melden, wenn wir weitere Diskussionen benötigen, um mit diesen Verbesserungen fortzufahren.\n\nVielen Dank, dass Sie sich an uns gewandt haben.\n\nMit freundlichen Grüßen,\nIT Beratungsunternehmen Support|Request|Technical Support   |high    |de      |IT Consulting Firm|Technical Support|Product Support |Feature Request   |General Inquiry   |Compliance Issue    |Cloud Management  |Cost Management|IT Support|NULL |
# +------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+--------------------+--------+--------+------------------+-----------------+----------------+------------------+------------------+--------------------+------------------+---------------+----------+-----+

# %% [markdown]
# ## UDFs (User-Defined Functions)
#
# UDFs (User-Defined Functions) allow you to create custom functions that can be applied to DataFrame columns in Spark SQL. They are useful when you need to perform operations that are not available in the built-in functions provided by Spark.

# %%
# Task 6: Create a UDF to detect whether a ticket is security-related

security_keywords = ["security", "cyber", "breach", "attack", "incident", "risk"]

# Create a function that checks if any of the security keywords (case insensitive) are present in the subject or body of the ticket
def is_security_ticket(subject, body):
    # Handle None values to avoid TypeError: unsupported operand type(s) for +: 'NoneType' and 'str'
    full_text = (str(subject or "") + " " + str(body or "")).lower()
    return any(keyword.lower() in full_text for keyword in security_keywords)

# Register for DataFrame use
isSecurityUDF = udf(is_security_ticket, BooleanType())

# %%
# Register for SQL use
spark.udf.register("is_security_ticket", is_security_ticket, BooleanType())
# Out:
# <function __main__.is_security_ticket(subject, body)>

# %%
# Apply the UDF to our tickets DataFrame
ticketsSecurityDF = ticketsDF.withColumn(
    "is_security_ticket",
    isSecurityUDF(col("subject"), col("body"))
)

# Print the results, showing the subject and whether it's a security ticket
ticketsSecurityDF.select("subject", "is_security_ticket").show(truncate=False)
# Out:
# +---------------------------------------------------------------------+------------------+
# |subject                                                              |is_security_ticket|
# +---------------------------------------------------------------------+------------------+
# |Problema crítico del servidor requiere atención inmediata            |false             |
# |Anfrage zur Verfügbarkeit des Dell XPS 13 9310                       |false             |
# |Erro na Autocompletação de Código do IntelliJ IDEA                   |false             |
# |Urgent Assistance Required: AWS Service                              |false             |
# |Problème d'affichage de MacBook Air                                  |false             |
# |Urgent: Issue with Zoom Screen Sharing Feature                       |true              |
# |Discrepancia de facturación en Google Workspace                      |false             |
# |Service outage resolution requested for ongoing issues               |false             |
# |Surface Pro 7 Issue                                                  |false             |
# |Problèmes de déploiement avec les ressources AWS                     |false             |
# |Request for software development consultation and server admin advice|false             |
# |Unterstützung beim Einrichten des drahtlosen Druckens                |false             |
# |Urgent AWS Deployment Issues                                         |false             |
# |Solicitud urgente de orientación y solución de problemas             |false             |
# |Probleme mit der drahtlosen Funktion des Epson EcoTank ET-4760       |false             |
# |Urgente: Interrupción de red por el router ISR4331                   |false             |
# |Immediate Assistance Required for Network Disruption                 |true              |
# |Hilfestellung für die Integration von Google Workspace erforderlich  |false             |
# |NULL                                                                 |false             |
# |Assistance Needed for Chrome Crashes                                 |false             |
# +---------------------------------------------------------------------+------------------+
# only showing top 20 rows

# %%
# Count the security tickets
securityTicketCount = ticketsSecurityDF.filter(col("is_security_ticket") == True).count()

# %%
# Use the same UDF but on SQL
# Ensure the table is registered
ticketsDF.createOrReplaceTempView("tickets")

spark.sql("""
SELECT subject, is_security_ticket(subject, body) as is_security
FROM tickets
LIMIT 5
""").show(truncate=False)
# Out:
# +---------------------------------------------------------+-----------+
# |subject                                                  |is_security|
# +---------------------------------------------------------+-----------+
# |Problema crítico del servidor requiere atención inmediata|false      |
# |Anfrage zur Verfügbarkeit des Dell XPS 13 9310           |false      |
# |Erro na Autocompletação de Código do IntelliJ IDEA       |false      |
# |Urgent Assistance Required: AWS Service                  |false      |
# |Problème d'affichage de MacBook Air                      |false      |
# +---------------------------------------------------------+-----------+

# %%
# Count the security tickets with SQL
spark.sql("""
SELECT count(*) as security_ticket_count
FROM tickets
WHERE is_security_ticket(subject, body) = true
""").show()
# Out:
# +---------------------+
# |security_ticket_count|
# +---------------------+
# |                  165|
# +---------------------+

# %% [markdown]
# ## Working with arrays
#
# As you might have notices we have multiple columns for tags. Let's convert these tags columns to an array and perform operations on an array column.

# %%
# Task 7: Create new column "tags" of type array for our Dataframe, containing all the tags (tag_1 to tag_8)
tagsDF = ticketsDF.withColumn("tags", array("tag_1", "tag_2", "tag_3", "tag_4", "tag_5", "tag_6", "tag_7", "tag_8"))

# %%
# Task 8: Explode tags to find most common tags
explodedTagsDF = tagsDF.select(explode("tags").alias("tag"))
explodedTagsDF.show()
# Out:
# +--------------------+
# |                 tag|
# +--------------------+
# |        Urgent Issue|
# |  Service Disruption|
# |     Incident Report|
# |    Service Recovery|
# |  System Maintenance|
# |                NULL|
# |                NULL|
# |                NULL|
# |       Sales Inquiry|
# |     Product Support|
# |    Customer Service|
# |         Order Issue|
# |Returns and Excha...|
# |                NULL|
# |                NULL|
# |                NULL|
# |   Technical Support|
# |        Software Bug|
# |  Problem Resolution|
# |        Urgent Issue|
# +--------------------+
# only showing top 20 rows

# %%
# Count the number of tags and print the results from most used to least used, ignoring NULL values
tagCountsDF = (
    explodedTagsDF.filter(col("tag").isNotNull())
    .groupBy("tag")
    .count()
    .orderBy(col("count").desc())
)

tagCountsDF.show()
# Out:
# +--------------------+-----+
# |                 tag|count|
# +--------------------+-----+
# |   Technical Support| 3164|
# |  Problem Resolution| 2835|
# |     Product Support| 1850|
# |        Urgent Issue| 1766|
# |    Customer Service| 1077|
# |        Software Bug| 1041|
# |          IT Support| 1026|
# |  Technical Guidance| 1022|
# |  Service Disruption|  892|
# |    Hardware Failure|  814|
# |  Performance Tuning|  735|
# |    Service Recovery|  656|
# |     General Inquiry|  594|
# |  Account Assistance|  566|
# |       Network Issue|  547|
# |  System Maintenance|  435|
# |     Incident Report|  398|
# |       Billing Issue|  380|
# |Returns and Excha...|  318|
# |Service Notification|  305|
# +--------------------+-----+
# only showing top 20 rows

# %%
# Stop the Spark Session
spark.stop()
